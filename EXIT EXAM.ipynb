# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("C:\\Users\\Gouri\\Downloads\\Train.csv")
df_train
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 5630  9801-GDWGV  Female            0.0      No         No    39.0
# 5631  6542-LWGXJ    Male            0.0     Yes         No     3.0
# 5632  5567-GZKQY    Male            0.0      No         No    58.0
# 5633  1222-LRYKO    Male            0.0      No        Yes     6.0
# 5634  2320-JRSDE  Female            0.0     Yes        Yes     1.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
df_test = pd.read_csv("C:\\Users\\Gouri\\Downloads\\test.csv")
df_test
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     2087-QAREY  Female              0     Yes         No    22.0
# 1     0601-WZHJF    Male              0     Yes         No    14.0
# 2     4423-JWZJN    Male              0     Yes        Yes    64.0
# 3     5143-WMWOG    Male              0      No         No     1.0
# 4     6490-FGZAT    Male              0      No         No     6.0
# ...          ...     ...            ...     ...        ...     ...
# 1403  6840-RESVB    Male              0     Yes        Yes    24.0
# 1404  2234-XADUH  Female              0     Yes        Yes    72.0
# 1405  4801-JZAZL  Female              0     Yes        Yes    11.0
# 1406  8361-LTMKD    Male              1     Yes         No     4.0
# 1407  3186-AJIEK    Male              0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0             Yes                No             DSL                   No
# ...

# %% [markdown]
# Analysing the dataset

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5635 entries, 0 to 5634
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5635 non-null   object
#  1   gender            5635 non-null   object
#  2   SeniorCitizen     5628 non-null   float64
#  3   Partner           5635 non-null   object
#  4   Dependents        5635 non-null   object
#  5   tenure            5622 non-null   float64
#  6   PhoneService      5622 non-null   object
#  7   MultipleLines     5622 non-null   object
#  8   InternetService   5598 non-null   object
#  9   OnlineSecurity    5620 non-null   object
#  10  OnlineBackup      5620 non-null   object
#  11  DeviceProtection  5620 non-null   object
#  12  TechSupport       5620 non-null   object
#  13  StreamingTV       5613 non-null   object
#  14  StreamingMovies   5621 non-null   object
#  15  Contract          5610 non-null   object
# ...

# %%
df_train.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    5628.000000  5622.000000     5619.000000
# mean        0.160270    32.286375       64.854983
# std         0.366889    24.591460       30.105189
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.550000
# 50%         0.000000    29.000000       70.400000
# 75%         0.000000    55.000000       89.900000
# max         1.000000    72.000000      118.750000

# %%
df_train.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        7
# Partner              0
# Dependents           0
# tenure              13
# PhoneService        13
# MultipleLines       13
# InternetService     37
# OnlineSecurity      15
# OnlineBackup        15
# DeviceProtection    15
# TechSupport         15
# StreamingTV         22
# StreamingMovies     14
# Contract            25
# PaperlessBilling    14
# PaymentMethod        1
# MonthlyCharges      16
# TotalCharges         7
# Churn                0
# dtype: int64

# %%
numerical = df_train.select_dtypes(include="number")
numerical
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0               0.0     1.0           29.85
# 1               0.0    34.0           56.95
# 2               0.0     2.0           53.85
# 3               0.0    45.0           42.30
# 4               0.0     2.0           70.70
# ...             ...     ...             ...
# 5630            0.0    39.0          103.45
# 5631            0.0     3.0           25.00
# 5632            0.0    58.0           20.30
# 5633            0.0     6.0           26.35
# 5634            0.0     1.0           19.90
#
# [5635 rows x 3 columns]

# %%
for col in numerical:
    numerical[col] = numerical[col].fillna(numerical[col].median())
numerical
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0               0.0     1.0           29.85
# 1               0.0    34.0           56.95
# 2               0.0     2.0           53.85
# 3               0.0    45.0           42.30
# 4               0.0     2.0           70.70
# ...             ...     ...             ...
# 5630            0.0    39.0          103.45
# 5631            0.0     3.0           25.00
# 5632            0.0    58.0           20.30
# 5633            0.0     6.0           26.35
# 5634            0.0     1.0           19.90
#
# [5635 rows x 3 columns]

# %%
numerical.isna().sum()
# Out:
# SeniorCitizen     0
# tenure            0
# MonthlyCharges    0
# dtype: int64

# %%
categorical = df_train.select_dtypes(include="object")
categorical
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 0     7590-VHVEG  Female     Yes         No           No  No phone service
# 1     5575-GNVDE    Male      No         No          Yes                No
# 2     3668-QPYBK    Male      No         No          Yes                No
# 3     7795-CFOCW    Male      No         No           No  No phone service
# 4     9237-HQITU  Female      No         No          Yes                No
# ...          ...     ...     ...        ...          ...               ...
# 5630  9801-GDWGV  Female      No         No          Yes               Yes
# 5631  6542-LWGXJ    Male     Yes         No           No  No phone service
# 5632  5567-GZKQY    Male      No         No          Yes                No
# 5633  1222-LRYKO    Male      No        Yes          Yes               Yes
# 5634  2320-JRSDE  Female     Yes        Yes          Yes                No
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# ...

# %%
for col in categorical:
    categorical[col]=categorical[col].fillna(categorical[col].mode()[0])

categorical
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 0     7590-VHVEG  Female     Yes         No           No  No phone service
# 1     5575-GNVDE    Male      No         No          Yes                No
# 2     3668-QPYBK    Male      No         No          Yes                No
# 3     7795-CFOCW    Male      No         No           No  No phone service
# 4     9237-HQITU  Female      No         No          Yes                No
# ...          ...     ...     ...        ...          ...               ...
# 5630  9801-GDWGV  Female      No         No          Yes               Yes
# 5631  6542-LWGXJ    Male     Yes         No           No  No phone service
# 5632  5567-GZKQY    Male      No         No          Yes                No
# 5633  1222-LRYKO    Male      No        Yes          Yes               Yes
# 5634  2320-JRSDE  Female     Yes        Yes          Yes                No
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# ...

# %%
categorical.isna().sum()
# Out:
# customerID          0
# gender              0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df = pd.concat([numerical, categorical], axis=1)
df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  customerID  gender Partner  \
# 0            0.0     1.0           29.85  7590-VHVEG  Female     Yes
# 1            0.0    34.0           56.95  5575-GNVDE    Male      No
# 2            0.0     2.0           53.85  3668-QPYBK    Male      No
# 3            0.0    45.0           42.30  7795-CFOCW    Male      No
# 4            0.0     2.0           70.70  9237-HQITU  Female      No
#
#   Dependents PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 0         No           No  No phone service             DSL  ...          Yes
# 1         No          Yes                No             DSL  ...           No
# 2         No          Yes                No             DSL  ...          Yes
# 3         No           No  No phone service             DSL  ...           No
# 4         No          Yes                No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.isna().sum()
# Out:
# SeniorCitizen       0
# tenure              0
# MonthlyCharges      0
# customerID          0
# gender              0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               8
# PhoneService        11
# MultipleLines       12
# InternetService      8
# OnlineSecurity       8
# OnlineBackup         8
# DeviceProtection    10
# TechSupport         10
# StreamingTV          8
# StreamingMovies     15
# Contract            15
# PaperlessBilling    15
# PaymentMethod        8
# MonthlyCharges       8
# TotalCharges         0
# dtype: int64

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1408 non-null   object
#  1   gender            1408 non-null   object
#  2   SeniorCitizen     1408 non-null   int64
#  3   Partner           1408 non-null   object
#  4   Dependents        1408 non-null   object
#  5   tenure            1400 non-null   float64
#  6   PhoneService      1397 non-null   object
#  7   MultipleLines     1396 non-null   object
#  8   InternetService   1400 non-null   object
#  9   OnlineSecurity    1400 non-null   object
#  10  OnlineBackup      1400 non-null   object
#  11  DeviceProtection  1398 non-null   object
#  12  TechSupport       1398 non-null   object
#  13  StreamingTV       1400 non-null   object
#  14  StreamingMovies   1393 non-null   object
#  15  Contract          1393 non-null   object
# ...

# %%
num = df_test.select_dtypes(include='number')
num
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0                 0    22.0           54.70
# 1                 0    14.0           46.35
# 2                 0    64.0           90.25
# 3                 0     1.0           19.95
# 4                 0     6.0           20.65
# ...             ...     ...             ...
# 1403              0    24.0           84.80
# 1404              0    72.0          103.20
# 1405              0    11.0           29.60
# 1406              1     4.0           74.40
# 1407              0    66.0          105.65
#
# [1408 rows x 3 columns]

# %%
num.isna().sum()
# Out:
# SeniorCitizen     0
# tenure            8
# MonthlyCharges    8
# dtype: int64

# %%
for col in num:
    num[col] = num[col].fillna(num[col].median())
num
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0                 0    22.0           54.70
# 1                 0    14.0           46.35
# 2                 0    64.0           90.25
# 3                 0     1.0           19.95
# 4                 0     6.0           20.65
# ...             ...     ...             ...
# 1403              0    24.0           84.80
# 1404              0    72.0          103.20
# 1405              0    11.0           29.60
# 1406              1     4.0           74.40
# 1407              0    66.0          105.65
#
# [1408 rows x 3 columns]

# %%
num.isna().sum()
# Out:
# SeniorCitizen     0
# tenure            0
# MonthlyCharges    0
# dtype: int64

# %%
cat = df_test.select_dtypes(include='object')
cat
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 0     2087-QAREY  Female     Yes         No          Yes                No
# 1     0601-WZHJF    Male     Yes         No           No  No phone service
# 2     4423-JWZJN    Male     Yes        Yes          Yes               Yes
# 3     5143-WMWOG    Male      No         No          Yes                No
# 4     6490-FGZAT    Male      No         No          Yes                No
# ...          ...     ...     ...        ...          ...               ...
# 1403  6840-RESVB    Male     Yes        Yes          Yes               Yes
# 1404  2234-XADUH  Female     Yes        Yes          Yes               Yes
# 1405  4801-JZAZL  Female     Yes        Yes           No  No phone service
# 1406  8361-LTMKD    Male     Yes         No          Yes               Yes
# 1407  3186-AJIEK    Male      No         No          Yes                No
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# ...

# %%
for c in cat:
    cat[c]=cat[c].fillna(cat[c].mode()[0])

cat
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 0     2087-QAREY  Female     Yes         No          Yes                No
# 1     0601-WZHJF    Male     Yes         No           No  No phone service
# 2     4423-JWZJN    Male     Yes        Yes          Yes               Yes
# 3     5143-WMWOG    Male      No         No          Yes                No
# 4     6490-FGZAT    Male      No         No          Yes                No
# ...          ...     ...     ...        ...          ...               ...
# 1403  6840-RESVB    Male     Yes        Yes          Yes               Yes
# 1404  2234-XADUH  Female     Yes        Yes          Yes               Yes
# 1405  4801-JZAZL  Female     Yes        Yes           No  No phone service
# 1406  8361-LTMKD    Male     Yes         No          Yes               Yes
# 1407  3186-AJIEK    Male      No         No          Yes                No
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# ...

# %%
cat.isna().sum()
# Out:
# customerID          0
# gender              0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# TotalCharges        0
# dtype: int64

# %%
df_test = pd.concat([num, cat], axis=1)
df_test.isna().sum()
# Out:
# SeniorCitizen       0
# tenure              0
# MonthlyCharges      0
# customerID          0
# gender              0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# TotalCharges        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_test.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
sns.heatmap(numerical.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(numerical)
# Out:
# <Axes: >

# %%
def remove_outliers(numerical, column_name):
    q1 = numerical[column_name].quantile(0.25)
    q3 = numerical[column_name].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 1.5 * iqr
    lower_bound = q1 - 1.5 * iqr
    numerical[column_name] = numerical[column_name].clip(upper=upper_bound)
    numerical[column_name] = numerical[column_name].clip(lower=lower_bound)
    return numerical[column_name]

for col in numerical:
  numerical[col] = remove_outliers(numerical, col)

numerical
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0               0.0     1.0           29.85
# 1               0.0    34.0           56.95
# 2               0.0     2.0           53.85
# 3               0.0    45.0           42.30
# 4               0.0     2.0           70.70
# ...             ...     ...             ...
# 5630            0.0    39.0          103.45
# 5631            0.0     3.0           25.00
# 5632            0.0    58.0           20.30
# 5633            0.0     6.0           26.35
# 5634            0.0     1.0           19.90
#
# [5635 rows x 3 columns]

# %%
sns.boxplot(numerical)
# Out:
# <Axes: >

# %%
sns.boxplot(num)
# Out:
# <Axes: >

# %%
def remove_outliers(num, column_name):
    q1 = num[column_name].quantile(0.25)
    q3 = num[column_name].quantile(0.75)
    iqr = q3 - q1
    upper_bound = q3 + 1.5 * iqr
    lower_bound = q1 - 1.5 * iqr
    num[column_name] = num[column_name].clip(upper=upper_bound)
    num[column_name] = num[column_name].clip(lower=lower_bound)
    return num[column_name]

for col in numerical:
  num[col] = remove_outliers(num, col)

num
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0                 0    22.0           54.70
# 1                 0    14.0           46.35
# 2                 0    64.0           90.25
# 3                 0     1.0           19.95
# 4                 0     6.0           20.65
# ...             ...     ...             ...
# 1403              0    24.0           84.80
# 1404              0    72.0          103.20
# 1405              0    11.0           29.60
# 1406              0     4.0           74.40
# 1407              0    66.0          105.65
#
# [1408 rows x 3 columns]

# %%
sns.boxplot(num)
# Out:
# <Axes: >

# %%
numerical.hist(bins=16, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'SeniorCitizen'}>,
#         <Axes: title={'center': 'tenure'}>],
#        [<Axes: title={'center': 'MonthlyCharges'}>, <Axes: >]],
#       dtype=object)

# %%
for c in categorical:
    plt.figure(figsize=(10,5))
    sns.histplot(categorical[c])
    plt.title('Histogram of {} column'.format(c))
    plt.xlabel(c)
    plt.ylabel('Count')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 7
#       5 plt.xlabel(c)
#       6 plt.ylabel('Count')
# ----> 7 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:612, in show(*args, **kwargs)
#     568 """
#     569 Display all open figures.
#     570
#    (...)
#     609 explicitly there.
#     610 """
#     611 _warn_if_gui_out_of_main_thread()
# --> 612 return _get_backend_mod().show(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# ...

# %%
numerical.hist(bins=16, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'SeniorCitizen'}>,
#         <Axes: title={'center': 'tenure'}>],
#        [<Axes: title={'center': 'MonthlyCharges'}>, <Axes: >]],
#       dtype=object)

# %%
sns.countplot(x='Churn', data=df, palette='viridis', legend=True)
plt.xlabel("x")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Gouri\AppData\Local\Temp\ipykernel_27156\2380700807.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Churn', data=df, palette='viridis', legend=True)

# %%
sns.countplot(x='InternetService', data=df, palette='viridis', legend=True)
plt.title('Class Imbalance Distribution')
plt.xlabel("Internet Service ")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Gouri\AppData\Local\Temp\ipykernel_27156\1143355726.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='InternetService', data=df, palette='viridis', legend=True)

# %%
sns.countplot(x='gender', data=df, palette='viridis', legend=True)
plt.title('Class Imbalance Distribution')
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Gouri\AppData\Local\Temp\ipykernel_27156\3866259772.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='gender', data=df, palette='viridis', legend=True)

# %%
sns.countplot(x='Dependents', data=df)
plt.title('Class Imbalance Distribution')
plt.xlabel('Dependents')
plt.ylabel('Number')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.countplot(x='gender',data=df,hue='Churn')
plt.title('Distribution of Gender')
plt.xlabel('gender')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(x='tenure', hue='Churn', data=df, bins=14, alpha=0.8, multiple='stack')
plt.title('Churn Count by Tenure')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
le = LabelEncoder()

# %%
df['gender']=le.fit_transform(df['gender'])

# %%
df_test['gender']=le.fit_transform(df_test['gender'])

# %%
df['Partner']=le.fit_transform(df['Partner'])

# %%
df_test['Partner']=le.fit_transform(df_test['Partner'])

# %%
df['PhoneService']=le.fit_transform(df['PhoneService'])

# %%
df_test['PhoneService']=le.fit_transform(df_test['PhoneService'])

# %%
df['Dependents']=le.fit_transform(df['Dependents'])

# %%
df_test['Dependents']=le.fit_transform(df_test['Dependents'])

# %%
df['PaperlessBilling']=le.fit_transform(df['PaperlessBilling'])

# %%
df_test['PaperlessBilling']=le.fit_transform(df_test['PaperlessBilling'])

# %%
df['customerID']=le.fit_transform(df['customerID'])

# %%
df_test['customerID']=le.fit_transform(df_test['customerID'])

# %%
onehot_cols=['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies','Contract', 'PaymentMethod']
df = pd.get_dummies(df, columns=onehot_cols, dtype='int64')

# %%
df
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  customerID  gender  Partner  \
# 0               0.0     1.0           29.85        4291       0        1
# 1               0.0    34.0           56.95        3142       1        0
# 2               0.0     2.0           53.85        2010       1        0
# 3               0.0    45.0           42.30        4425       1        0
# 4               0.0     2.0           70.70        5222       0        0
# ...             ...     ...             ...         ...     ...      ...
# 5630            0.0    39.0          103.45        5532       0        0
# 5631            0.0     3.0           25.00        3689       1        1
# 5632            0.0    58.0           20.30        3136       1        0
# 5633            0.0     6.0           26.35         662       1        0
# 5634            0.0     1.0           19.90        1253       0        1
#
#       Dependents  PhoneService  PaperlessBilling TotalCharges  ...  \
# ...

# %%
std = StandardScaler()
minmax = MinMaxScaler()

# %%
df['tenure']= minmax.fit_transform(df[['tenure']])

# %%
df['MonthlyCharges'] = std.fit_transform(df[['MonthlyCharges']])

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce').fillna(0).astype(int)
df['TotalCharges'] = std.fit_transform(df[['TotalCharges']])

# %%
df
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  customerID  gender  Partner  \
# 0               0.0  0.013889       -1.164981        4291       0        1
# 1               0.0  0.472222       -0.263487        3142       1        0
# 2               0.0  0.027778       -0.366610        2010       1        0
# 3               0.0  0.625000       -0.750826        4425       1        0
# 4               0.0  0.027778        0.193914        5222       0        0
# ...             ...       ...             ...         ...     ...      ...
# 5630            0.0  0.541667        1.283358        5532       0        0
# 5631            0.0  0.041667       -1.326319        3689       1        1
# 5632            0.0  0.805556       -1.482667        3136       1        0
# 5633            0.0  0.083333       -1.281411         662       1        0
# 5634            0.0  0.013889       -1.495973        1253       0        1
#
# ...

# %%
onehot_cols=['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies','Contract', 'PaymentMethod']
df_test = pd.get_dummies(df_test, columns=onehot_cols, dtype='int64')

# %%
df_test['tenure']= minmax.fit_transform(df_test[['tenure']])

# %%
df_test['TotalCharges'] = pd.to_numeric(df_test['TotalCharges'], errors='coerce').fillna(0).astype(int)
df_test['TotalCharges'] = std.fit_transform(df_test[['TotalCharges']])

# %%
df_test['MonthlyCharges'] = std.fit_transform(df_test[['MonthlyCharges']])

# %%
df_test
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  customerID  gender  Partner  \
# 0                 0  0.305556       -0.322026         300       0        1
# 1                 0  0.194444       -0.600702          80       1        1
# 2                 0  0.888889        0.864436         644       1        1
# 3                 0  0.013889       -1.481788         764       1        0
# 4                 0  0.083333       -1.458426         937       1        0
# ...             ...       ...             ...         ...     ...      ...
# 1403              0  0.333333        0.682546         988       1        1
# 1404              0  1.000000        1.296636         324       0        1
# 1405              0  0.152778       -1.159725         707       0        1
# 1406              1  0.055556        0.335451        1183       1        1
# 1407              0  0.916667        1.378403         471       1        0
#
# ...

# %%
df=df.drop(['customerID'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5635 entries, 0 to 5634
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SeniorCitizen                            5635 non-null   float64
#  1   tenure                                   5635 non-null   float64
#  2   MonthlyCharges                           5635 non-null   float64
#  3   gender                                   5635 non-null   int32
#  4   Partner                                  5635 non-null   int32
#  5   Dependents                               5635 non-null   int32
#  6   PhoneService                             5635 non-null   int32
#  7   PaperlessBilling                         5635 non-null   int32
#  8   TotalCharges                             5635 non-null   float64
#  9   Churn                                    5635 non-null   object
# ...

# %%
df_test=df_test.drop(['customerID'], axis=1)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 40 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   SeniorCitizen                            1408 non-null   int64
#  1   tenure                                   1408 non-null   float64
#  2   MonthlyCharges                           1408 non-null   float64
#  3   gender                                   1408 non-null   int32
#  4   Partner                                  1408 non-null   int32
#  5   Dependents                               1408 non-null   int32
#  6   PhoneService                             1408 non-null   int32
#  7   PaperlessBilling                         1408 non-null   int32
#  8   TotalCharges                             1408 non-null   float64
#  9   MultipleLines_No                         1408 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['Churn'], axis=1)
y=df['Churn']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=52)

# %%
x_train.shape
# Out:
# (3944, 40)

# %%
y_train.shape
# Out:
# (3944,)

# %%
x_test.shape
# Out:
# (1691, 40)

# %%
y_test.shape
# Out:
# (1691,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import KFold, cross_val_score

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix

# %%
lr = LogisticRegression(random_state=42)

lr.fit(x_train, y_train)
y_pred=lr.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred,average="weighted")
recall=recall_score(y_test,y_pred,average="weighted")
f1=f1_score(y_test,y_pred,average="weighted")
print("Accuracy is",accuracy,"\nPrecison is",precision,"\nRecall is",recall,"\nF1 score is",f1)
# Out:
# Accuracy is 0.814902424600828
# Precison is 0.8063696862278641
# Recall is 0.814902424600828
# F1 score is 0.8068878989964875

# %%
y_pred.shape
# Out:
# (1691,)

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred_knn=knn.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred_knn)
precision=precision_score(y_test,y_pred_knn,average="weighted")
recall=recall_score(y_test,y_pred_knn,average="weighted")
f1=f1_score(y_test,y_pred_knn,average="weighted")
print("Accuracy is",accuracy,"\nPrecison is",precision,"\nRecall is",recall,"\nF1 score is",f1)
# Out:
# Accuracy is 0.7628622117090479
# Precison is 0.7508374393831267
# Recall is 0.7628622117090479
# F1 score is 0.7546849733055392

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(x_train, y_train)
y_pred_rf=rf.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred_rf)
precision=precision_score(y_test,y_pred_rf,average="weighted")
recall=recall_score(y_test,y_pred_rf,average="weighted")
f1=f1_score(y_test,y_pred_rf,average="weighted")
print("Accuracy is",accuracy,"\nPrecison is",precision,"\nRecall is",recall,"\nF1 score is",f1)
# Out:
# Accuracy is 0.7894736842105263
# Precison is 0.7762463812004119
# Recall is 0.7894736842105263
# F1 score is 0.7758931916274731

# %%
pip install xgboost
# Out:
# ...
#
# ...

# %%
svm = SVC(random_state=42)

# Train the model
svm.fit(x_train, y_train)
y_pred_svm=svm.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred_svm)
precision=precision_score(y_test,y_pred_svm,average="weighted")
recall=recall_score(y_test,y_pred_svm,average="weighted")
f1=f1_score(y_test,y_pred_svm,average="weighted")
print("Accuracy is",accuracy,"\nPrecison is",precision,"\nRecall is",recall,"\nF1 score is",f1)
# Out:
# Accuracy is 0.8018923713778829
# Precison is 0.7908009501047845
# Recall is 0.8018923713778829
# F1 score is 0.7887644556814005

# %%
gb = GradientBoostingClassifier(random_state=42)

# Train the model
gb.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred_gb=gb.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred_gb)
precision=precision_score(y_test,y_pred_gb,average="weighted")
recall=recall_score(y_test,y_pred_gb,average="weighted")
f1=f1_score(y_test,y_pred_gb,average="weighted")
print("Accuracy is",accuracy,"\nPrecison is",precision,"\nRecall is",recall,"\nF1 score is",f1)
# Out:
# Accuracy is 0.8095801301005322
# Precison is 0.7999282484165552
# Recall is 0.8095801301005322
# F1 score is 0.7994391539022199

# %%
current_params = lr.get_params()
current_params
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'deprecated',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 42,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
import numpy as np
param_grid = [
    {'penalty':['l1','l2','elasticnet','none'],
    'C' : np.logspace(-4,4,20),
    'solver': ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter'  : [100,1000,2500,5000]
}
]

# %%
random_search_lr = RandomizedSearchCV(estimator=lr, param_distributions=param_grid, scoring='accuracy',
                                     cv=5, n_jobs=-1, random_state=42, n_iter=150, verbose = 1)
random_search_lr.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# C:\Users\Gouri\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 455 fits failed out of a total of 750.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Gouri\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Gouri\anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
best_params = random_search_lr.best_params_

# %%
best_score = random_search_lr.best_score_

# %%
best_params
# Out:
# {'solver': 'liblinear',
#  'penalty': 'l2',
#  'max_iter': 2500,
#  'C': 0.03359818286283781}

# %%
best_score
# Out:
# 0.7981760629982049

# %%
tuned_lr_model = random_search_lr.best_estimator_
tuned_lr_model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=0.03359818286283781, max_iter=2500, random_state=42,
#                    solver='liblinear')

# %%
random_search_lr_pred = tuned_lr_model.predict(x_test)
original_lr_model = lr.predict(x_test)

# %%
confusion_matrix_lr = confusion_matrix(y_test, random_search_lr_pred)

confusion_matrix_lr
# Out:
# array([[1134,   99],
#        [ 224,  234]], dtype=int64)

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(confusion_matrix_lr, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Churn', 'No Churn'],
            yticklabels=['Churn', 'No Churn'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
lr = LogisticRegression(random_state=42)

lr.fit(x_train, y_train)
y_pred_test=lr.predict(df_test)

# %%
y_pred_test
# Out:
# array(['No', 'Yes', 'No', ..., 'No', 'Yes', 'No'], dtype=object)
